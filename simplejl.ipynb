# %% [markdown]
# ## Introduction
#
# This is a simple Julia 0.6 document.

# %%
versioninfo()
now()
# Out:
# Julia Version 0.6.0
# Commit 903644385b (2017-06-19 13:05 UTC)
# Platform Info:
#   OS: macOS (x86_64-apple-darwin13.4.0)
#   CPU: Intel(R) Core(TM) i7-4850HQ CPU @ 2.30GHz
#   WORD_SIZE: 64
#   BLAS: libopenblas (USE64BITINT DYNAMIC_ARCH NO_AFFINITY Haswell)
#   LAPACK: libopenblas64_
#   LIBM: libopenlibm
#   LLVM: libLLVM-3.9.1 (ORCJIT, haswell)
# 2017-07-11T07:09:14.348

# %% [markdown]
# Simple plotting:

# %%
using PyPlot
t = 0:0.01:2pi
plot(t, sin.(3t))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x132a17c10>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x132aff950>
